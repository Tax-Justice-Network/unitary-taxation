# %% [markdown]
# # Specific Country Requests
#
# ## 0. Load Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Show all columns
pd.set_option('display.max_columns', None)

pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Concatenate Country Results

# %%
# Concatenate Final Results
sotj_countries_2016 = pd.read_csv('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_sample_countries_2016.csv')
sotj_countries_2017 = pd.read_csv('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_sample_countries_2017.csv')
sotj_countries_2018 = pd.read_csv('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_sample_countries_2018.csv')
sotj_countries_2019 = pd.read_csv('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_sample_countries_2019.csv')
sotj_countries_2020 = pd.read_csv('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_sample_countries_2020.csv')
sotj_countries_2021 = pd.read_csv('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_sample_countries_2021.csv')

# Add a column with the value 2016 to sotj_countries_2016
sotj_countries_2016['year'] = 2016
sotj_countries_2017['year'] = 2017
sotj_countries_2018['year'] = 2018
sotj_countries_2019['year'] = 2019
sotj_countries_2020['year'] = 2020
sotj_countries_2021['year'] = 2021


#Concatenate all of the above
sotj_countries = pd.concat([sotj_countries_2016, sotj_countries_2017, sotj_countries_2018, sotj_countries_2019, sotj_countries_2020, sotj_countries_2021])

# Sort by iso_partner and then year
sotj_countries = sotj_countries.sort_values(by=['iso_partner', 'year'])

# Order columns first iso_partner, then year, and then the rest

# Order columns first iso_partner, then year, and then the rest
cols = ['iso_partner', 'year'] + [col for col in sotj_countries.columns if col not in ['iso_partner', 'year']]
sotj_countries = sotj_countries[cols]

sotj_countries
# Out:
#     iso_partner  year  negative_misalignment  positive_misalignment  \
# 0           ABW  2016                  -0.00                  26.64
# 0           ABW  2017               1,047.96                   0.00
# 0           ABW  2018                   3.69                   0.27
# 0           ABW  2019                   0.12                   0.00
# 0           ABW  2020                  51.34                   0.03
# ..          ...   ...                    ...                    ...
# 214         ZWE  2017                 148.61                   0.00
# 212         ZWE  2018                 175.34                   5.29
# 209         ZWE  2019                 697.04                   0.06
# 211         ZWE  2020                 149.84                   4.75
# 210         ZWE  2021                  66.18                 164.57
#
#      theoretical_profit  reported_profit partner_jurisdiction  \
# 0                 20.74           195.17                Aruba
# 0              6,273.07            65.84                Aruba
# 0                 72.93           101.65                Aruba
# 0                 59.89            84.36                Aruba
# 0                 39.21           -14.51                Aruba
# ..                  ...              ...                  ...
# 214              521.19           285.33             Zimbabwe
# 212              923.19           698.22             Zimbabwe
# 209            1,184.45           503.08             Zimbabwe
# 211              300.21           559.34             Zimbabwe
# 210              840.66         2,103.72             Zimbabwe
#
#      etr_average_corrected  cit  tax_revenue_current_usd  \
# 0                     0.15 0.25                      NaN
# 0                     0.15 0.25                      NaN
# 0                     0.15 0.25                      NaN
# 0                     0.20 0.25                      NaN
# 0                     0.25 0.25                      NaN
# ..                     ...  ...                      ...
# 214                   0.18 0.26         2,791,491,447.98
# 212                   0.18 0.26         2,464,280,179.53
# 209                   0.19 0.26                      NaN
# 211                   0.18 0.25                      NaN
# 210                   0.18 0.25                      NaN
#
#      gvt_health_expenditure               region_tjn  ukt  oecd  oecd_oct  \
# 0                       NaN  Caribbean/American isl. 0.00  0.00      1.00
# 0                       NaN  Caribbean/American isl. 0.00  0.00      1.00
# 0                       NaN  Caribbean/American isl. 0.00  0.00      1.00
# 0                       NaN  Caribbean/American isl. 0.00  0.00      1.00
# 0                       NaN  Caribbean/American isl. 0.00  0.00      1.00
# ..                      ...                      ...  ...   ...       ...
# 214          341,835,130.00                   Africa 0.00  0.00      0.00
# 212          589,006,540.00                   Africa 0.00  0.00      0.00
# 209          120,051,500.00                   Africa 0.00  0.00      0.00
# 211          175,429,800.00                   Africa 0.00  0.00      0.00
# 210          328,520,941.52                   Africa 0.00  0.00      0.00
#
#      nld_oct  tax_revenue_loss  tax_revenue_gain  \
# 0       1.00             -0.00              4.05
# 0       1.00            261.99              0.00
# 0       1.00              0.92              0.04
# 0       1.00              0.03              0.00
# 0       1.00             12.83              0.01
# ..       ...               ...               ...
# 214     0.00             38.27              0.00
# 212     0.00             45.15              0.94
# 209     0.00            179.49              0.01
# 211     0.00             37.04              0.84
# 210     0.00             16.36             29.37
#
#      tax_revenue_loss_pct_of_gvt_health_expenditure  \
# 0                                               NaN
# 0                                               NaN
# 0                                               NaN
# 0                                               NaN
# 0                                               NaN
# ..                                              ...
# 214                                            0.11
# 212                                            0.08
# 209                                            1.50
# 211                                            0.21
# 210                                            0.05
#
#      tax_revenue_loss_pct_of_total_tax_revenues  \
# 0                                           NaN
# 0                                           NaN
# 0                                           NaN
# 0                                           NaN
# 0                                           NaN
# ..                                          ...
# 214                                        0.01
# 212                                        0.02
# 209                                         NaN
# 211                                         NaN
# 210                                         NaN
#
#      tax_revenue_loss_caused_pct_of_total  tax_revenue_loss_caused_usd  \
# 0                                    0.00                         7.40
# 0                                    0.00                         0.00
# 0                                    0.00                         0.07
# 0                                    0.00                         0.00
# 0                                    0.00                         0.01
# ..                                    ...                          ...
# 214                                  0.00                         0.00
# 212                                  0.00                         1.44
# 209                                  0.00                         0.02
# 211                                  0.00                         1.19
# 210                                  0.00                        40.28
#
#      tax_revenue_loss_suffered_pct_of_total
# 0                                     -0.00
# 0                                      0.00
# 0                                      0.00
# 0                                      0.00
# 0                                      0.00
# ..                                      ...
# 214                                    0.00
# 212                                    0.00
# 209                                    0.00
# 211                                    0.00
# 210                                    0.00
#
# [1244 rows x 23 columns]

# %% [markdown]
# ## Filter for Spain

# %%
## Filter for Spain
sotj_spain = sotj_countries[sotj_countries['iso_partner'] == 'ESP']
sotj_spain
# Out:
#    iso_partner  year  negative_misalignment  positive_misalignment  \
# 49         ESP  2016               3,222.87               7,323.86
# 57         ESP  2017               7,577.97               6,175.68
# 58         ESP  2018              13,213.83               6,005.58
# 55         ESP  2019              32,770.87                  60.48
# 56         ESP  2020              33,826.17              39,239.42
# 57         ESP  2021              35,506.78              12,786.21
#
#     theoretical_profit  reported_profit partner_jurisdiction  \
# 49           15,335.56        17,213.01                Spain
# 57           91,804.11        85,694.05                Spain
# 58           98,766.15        78,594.67                Spain
# 55          115,234.63        66,301.38                Spain
# 56           14,857.05         2,971.58                Spain
# 57          132,938.88        88,873.37                Spain
#
#     etr_average_corrected  cit  tax_revenue_current_usd  \
# 49                   0.11 0.25       170,092,266,805.81
# 57                   0.11 0.25       180,110,718,344.16
# 58                   0.11 0.25       202,247,907,420.14
# 55                   0.12 0.25       191,699,934,536.83
# 56                   0.12 0.25       173,433,341,518.30
# 57                   0.12 0.25       217,406,592,877.60
#
#     gvt_health_expenditure region_tjn  ukt  oecd  oecd_oct  nld_oct  \
# 49       78,972,636,876.33     Europe 0.00  1.00      0.00     0.00
# 57       82,824,965,778.02     Europe 0.00  1.00      0.00     0.00
# 58       89,822,989,520.58     Europe 0.00  1.00      0.00     0.00
# 55       89,962,877,989.85     Europe 0.00  1.00      0.00     0.00
# 56      100,367,700,515.31     Europe 0.00  1.00      0.00     0.00
# 57      109,770,657,500.96     Europe 0.00  1.00      0.00     0.00
#
#     tax_revenue_loss  tax_revenue_gain  \
# 49            805.72            807.90
# 57          1,894.49            689.16
# 58          3,303.46            688.60
# 55          8,192.72              7.05
# 56          8,456.54          4,737.87
# 57          8,876.69          1,548.41
#
#     tax_revenue_loss_pct_of_gvt_health_expenditure  \
# 49                                            0.01
# 57                                            0.02
# 58                                            0.04
# 55                                            0.09
# 56                                            0.08
# 57                                            0.08
#
#     tax_revenue_loss_pct_of_total_tax_revenues  \
# 49                                        0.00
# 57                                        0.01
# 58                                        0.02
# 55                                        0.04
# 56                                        0.05
# 57                                        0.04
#
#     tax_revenue_loss_caused_pct_of_total  tax_revenue_loss_caused_usd  \
# 49                                  0.01                     2,034.68
# 57                                  0.01                     1,701.90
# 58                                  0.01                     1,631.09
# 55                                  0.00                        15.92
# 56                                  0.04                     9,863.62
# 57                                  0.01                     3,129.33
#
#     tax_revenue_loss_suffered_pct_of_total
# 49                                    0.01
# 57                                    0.01
# 58                                    0.01
# 55                                    0.03
# 56                                    0.03
# 57                                    0.03

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj_spain['year'], sotj_spain['negative_misalignment'], label='Profits Shifted out of the country')
plt.plot(sotj_spain['year'], sotj_spain['tax_revenue_loss'], label='Total tax revenue loss')

plt.title('Yearly total profit misalignment and tax revenue loss')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
# Table Piergiorgio
sotj_spain = sotj_spain[['iso_partner', 'year', 'negative_misalignment', 'positive_misalignment', 'theoretical_profit', 'reported_profit', 'partner_jurisdiction', 'etr_average_corrected', 'cit', 'tax_revenue_loss', 'tax_revenue_gain']]
sotj_spain

# Export to excel
sotj_spain.to_excel('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_Spain_2021.xlsx', index=False)

# %% [markdown]
# ## Filter for EU in 2021

# %%
# Filter for iso 3 == ESP, FRA, ITA, DEU, NLD, BEL, AUT, DNK, SWE, FIN, IRL, PRT, GRC, CZE, POL, HUN, ROU, BGR, HRV, SVK, SVN, EST, LVA, LTU, MLT, CYP, LUX
sotj_EU = sotj_countries_2021[sotj_countries_2021['iso_partner'].isin(['ESP', 'FRA', 'ITA', 'DEU', 'NLD', 'BEL', 'AUT', 'DNK', 'SWE', 'FIN', 'IRL', 'PRT', 'GRC', 'CZE', 'POL', 'HUN', 'ROU', 'BGR', 'HRV', 'SVK', 'SVN', 'EST', 'LVA', 'LTU', 'MLT', 'CYP', 'LUX'])]

# Sort ascending by positive misalignment
sotj_EU = sotj_EU.sort_values(by='positive_misalignment', ascending=False)

# Sort ascending by negative misalignment
#sotj_EU = sotj_EU.sort_values(by='negative_misalignment', ascending=False)

# Sort ascending by tax_revenue_loss
#sotj_EU = sotj_EU.sort_values(by='tax_revenue_loss', ascending=False)

# Sort ascending by tax_revenue_gain
#sotj_EU = sotj_EU.sort_values(by='tax_revenue_gain', ascending=False)

sotj_EU = sotj_EU[['iso_partner', 'year', 'negative_misalignment', 'positive_misalignment', 'theoretical_profit', 'reported_profit', 'partner_jurisdiction', 'etr_average_corrected', 'cit', 'tax_revenue_loss', 'tax_revenue_gain']]

sotj_EU.to_excel('../output/tables/2024/Final_Full_CBCR_Datasets/SOTJ_EU_2021.xlsx', index=False)
sotj_EU
# Out:
#     iso_partner  year  negative_misalignment  positive_misalignment  \
# 88          IRL  2021               4,365.47             140,174.18
# 52          DNK  2021               1,944.75              46,430.89
# 114         LUX  2021              83,042.40              36,849.23
# 141         NLD  2021              43,947.38              26,069.81
# 47          CYP  2021                 195.67              14,558.71
# 57          ESP  2021              35,506.78              12,786.21
# 126         MLT  2021                 431.01               7,528.79
# 12          AUT  2021               5,716.05               5,692.81
# 14          BEL  2021              21,723.04               5,601.37
# 177         SWE  2021              22,415.37               1,544.34
# 60          FIN  2021               3,079.77               1,456.71
# 58          EST  2021                 386.79               1,070.23
# 84          HUN  2021               5,924.41               1,017.02
# 175         SVK  2021               2,329.50                 999.38
# 113         LTU  2021                 704.19                 787.90
# 18          BGR  2021               1,848.89                 629.93
# 155         PRT  2021               7,119.08                 602.45
# 160         ROU  2021               9,090.15                 182.34
# 176         SVN  2021                 739.70                 151.08
# 83          HRV  2021                 666.09                  34.13
# 115         LVA  2021                 593.97                   6.22
# 152         POL  2021              22,340.99                   0.00
# 48          CZE  2021               8,444.24                   0.00
# 76          GRC  2021               2,648.79                   0.00
# 49          DEU  2021             125,868.40                   0.00
# 93          ITA  2021              29,592.42                   0.00
# 63          FRA  2021              70,272.44                   0.00
#
#      theoretical_profit  reported_profit partner_jurisdiction  \
# 88            28,269.82       159,107.08              Ireland
# 52            43,029.69        84,778.64              Denmark
# 114            9,996.70       -53,539.82           Luxembourg
# 141          101,201.25        68,897.69          Netherlands
# 47             5,244.89        15,227.33               Cyprus
# 57           132,938.88        88,873.37                Spain
# 126              943.89         7,876.36                Malta
# 12            20,782.24        18,471.16              Austria
# 14            61,367.63        37,588.06              Belgium
# 177           35,330.26         4,234.77               Sweden
# 60            10,319.20         6,502.42              Finland
# 58             1,040.94         1,529.54              Estonia
# 84            12,826.61         5,684.28              Hungary
# 175            8,348.96         6,488.46      Slovak Republic
# 113            3,824.43         3,417.19            Lithuania
# 18             5,985.24         4,067.49             Bulgaria
# 155           18,635.02        10,535.43             Portugal
# 160           28,568.18         8,813.27              Romania
# 176            3,042.95         2,255.44             Slovenia
# 83             2,497.34         1,638.63              Croatia
# 115            1,495.17           435.70               Latvia
# 152           53,587.57        24,139.45               Poland
# 48            22,670.92        13,426.91              Czechia
# 76             1,695.44          -921.22               Greece
# 49           359,502.39       193,276.43              Germany
# 93           134,470.75       108,468.84                Italy
# 63           264,502.72       180,570.81               France
#
#      etr_average_corrected  cit  tax_revenue_loss  tax_revenue_gain
# 88                    0.10 0.12            545.68         14,069.18
# 52                    0.10 0.22            427.84          4,538.82
# 114                   0.04 0.25         20,710.77          1,371.92
# 141                   0.09 0.25         10,986.84          2,310.44
# 47                    0.02 0.12             24.46            303.88
# 57                    0.12 0.25          8,876.69          1,548.41
# 126                   0.07 0.05             21.55            497.99
# 12                    0.10 0.25          1,429.01            569.13
# 14                    0.14 0.25          5,430.76            775.62
# 177                   0.09 0.21          4,617.57            141.86
# 60                    0.12 0.20            615.95            172.60
# 58                    0.02 0.20             77.36             25.99
# 84                    0.13 0.09            533.20            128.81
# 175                   0.08 0.21            489.19             75.20
# 113                   0.09 0.15            105.63             72.57
# 18                    0.08 0.10            184.89             53.15
# 155                   0.12 0.32          2,242.51             71.89
# 160                   0.13 0.16          1,454.42             23.96
# 176                   0.13 0.19            140.54             19.83
# 83                    0.14 0.18            119.90              4.85
# 115                   0.06 0.20            118.79              0.39
# 152                   0.20 0.19          4,244.79              0.00
# 48                    0.16 0.19          1,604.40              0.00
# 76                    0.19 0.22            582.73              0.00
# 49                    0.15 0.30         37,686.52              0.00
# 93                    0.18 0.28          8,229.65              0.00
# 63                    0.19 0.28         19,962.64              0.00

# %% [markdown]
# # Filter for Brazil

# %%
## Filter for Brazil
sotj_brazil = sotj_countries[sotj_countries['iso_partner'] == 'BRA']
sotj_brazil
# Out:
#    iso_partner  year  negative_misalignment  positive_misalignment  \
# 24         BRA  2016              13,524.38                   0.00
# 27         BRA  2017              22,326.31                   0.00
# 26         BRA  2018              25,304.05                   0.00
# 26         BRA  2019              14,576.14                 772.47
# 25         BRA  2020              10,301.20                   6.58
# 26         BRA  2021              20,266.16              35,065.86
#
#     theoretical_profit  reported_profit partner_jurisdiction  \
# 24           53,971.46        56,273.43               Brazil
# 27          113,656.85        94,074.66               Brazil
# 26          110,215.78        71,671.60               Brazil
# 26          109,856.27       108,073.56               Brazil
# 25           48,735.54        55,086.16               Brazil
# 26          120,396.49       127,277.36               Brazil
#
#     etr_average_corrected  cit  tax_revenue_current_usd  \
# 24                   0.22 0.34       246,197,315,551.43
# 27                   0.18 0.34       280,745,928,210.76
# 26                   0.19 0.34       267,222,655,483.46
# 26                   0.16 0.34       257,346,617,102.23
# 25                   0.15 0.34       187,751,803,965.09
# 26                   0.14 0.34       236,173,995,369.33
#
#     gvt_health_expenditure     region_tjn  ukt  oecd  oecd_oct  nld_oct  \
# 24       70,901,817,239.64  Latin America 0.00  0.00      0.00     0.00
# 27       81,573,764,736.43  Latin America 0.00  0.00      0.00     0.00
# 26       74,554,118,525.50  Latin America 0.00  0.00      0.00     0.00
# 26       73,377,051,360.95  Latin America 0.00  0.00      0.00     0.00
# 25       66,853,558,942.63  Latin America 0.00  0.00      0.00     0.00
# 26       74,306,913,856.19  Latin America 0.00  0.00      0.00     0.00
#
#     tax_revenue_loss  tax_revenue_gain  \
# 24          4,598.29              0.00
# 27          7,590.94              0.00
# 26          8,603.38              0.00
# 26          4,955.89            120.40
# 25          3,502.41              1.00
# 26          6,890.49          4,865.75
#
#     tax_revenue_loss_pct_of_gvt_health_expenditure  \
# 24                                            0.06
# 27                                            0.09
# 26                                            0.12
# 26                                            0.07
# 25                                            0.05
# 26                                            0.09
#
#     tax_revenue_loss_pct_of_total_tax_revenues  \
# 24                                        0.02
# 27                                        0.03
# 26                                        0.03
# 26                                        0.02
# 25                                        0.02
# 26                                        0.03
#
#     tax_revenue_loss_caused_pct_of_total  tax_revenue_loss_caused_usd  \
# 24                                  0.00                         0.00
# 27                                  0.00                         0.00
# 26                                  0.00                         0.00
# 26                                  0.00                       203.41
# 25                                  0.00                         1.65
# 26                                  0.02                     8,582.12
#
#     tax_revenue_loss_suffered_pct_of_total
# 24                                    0.03
# 27                                    0.03
# 26                                    0.03
# 26                                    0.02
# 25                                    0.01
# 26                                    0.02

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj_brazil['year'], sotj_brazil['negative_misalignment'], label='Total profit misalignment')
plt.plot(sotj_brazil['year'], sotj_brazil['tax_revenue_loss'], label='Total tax revenue loss')

plt.title('Yearly total profit misalignment and tax revenue loss')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %% [markdown]
# ## Filter for Danemark

# %%
## Filter for Denmark
sotj_denmark = sotj_countries[sotj_countries['iso_partner'] == 'DNK']
sotj_denmark
# Out:
#    iso_partner  year  negative_misalignment  positive_misalignment  \
# 83         ITA  2016              10,109.24                   0.00
# 96         ITA  2017               4,554.88               1,540.28
# 96         ITA  2018               7,113.79                 677.88
# 92         ITA  2019              11,190.09                   0.35
# 94         ITA  2020              12,485.89                  17.28
# 93         ITA  2021              29,592.42                   0.00
#
#     theoretical_profit  reported_profit partner_jurisdiction  \
# 83           60,384.62        35,689.12                Italy
# 96           80,319.94        82,174.10                Italy
# 96           97,870.24        88,094.13                Italy
# 92           82,900.80        76,891.41                Italy
# 94           35,585.13        24,907.64                Italy
# 93          134,470.75       108,468.84                Italy
#
#     etr_average_corrected  cit  tax_revenue_current_usd  \
# 83                   0.16 0.31       470,587,682,565.20
# 96                   0.16 0.28       484,243,484,621.06
# 96                   0.17 0.28       507,046,361,600.48
# 92                   0.17 0.28       494,311,806,053.03
# 94                   0.18 0.28       469,803,534,669.63
# 93                   0.18 0.28       539,764,829,745.07
#
#     gvt_health_expenditure region_tjn  ukt  oecd  oecd_oct  nld_oct  \
# 83      121,854,597,620.70     Europe 0.00  1.00      0.00     0.00
# 96      125,526,716,392.04     Europe 0.00  1.00      0.00     0.00
# 96      134,145,746,233.79     Europe 0.00  1.00      0.00     0.00
# 92      128,393,690,827.78     Europe 0.00  1.00      0.00     0.00
# 94      138,651,251,702.47     Europe 0.00  1.00      0.00     0.00
# 93      149,729,039,463.17     Europe 0.00  1.00      0.00     0.00
#
#     tax_revenue_loss  tax_revenue_gain  \
# 83          3,163.46              0.00
# 96          1,266.55            246.16
# 96          1,978.09            115.95
# 92          3,111.56              0.06
# 94          3,472.33              3.07
# 93          8,229.65              0.00
#
#     tax_revenue_loss_pct_of_gvt_health_expenditure  \
# 83                                            0.03
# 96                                            0.01
# 96                                            0.01
# 92                                            0.02
# 94                                            0.03
# 93                                            0.05
#
#     tax_revenue_loss_pct_of_total_tax_revenues  \
# 83                                        0.01
# 96                                        0.00
# 96                                        0.00
# 92                                        0.01
# 94                                        0.01
# 93                                        0.02
#
#     tax_revenue_loss_caused_pct_of_total  tax_revenue_loss_caused_usd  \
# 83                                  0.00                         0.00
# 96                                  0.00                       424.47
# 96                                  0.00                       184.11
# 92                                  0.00                         0.09
# 94                                  0.00                         4.34
# 93                                  0.00                         0.00
#
#     tax_revenue_loss_suffered_pct_of_total
# 83                                    0.02
# 96                                    0.00
# 96                                    0.01
# 92                                    0.01
# 94                                    0.01
# 93                                    0.02

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj_denmark['year'], sotj_denmark['negative_misalignment'], label='+ve profit misalignment')
plt.plot(sotj_denmark['year'], sotj_denmark['tax_revenue_loss'], label='Total tax revenue loss')

plt.title('Yearly total profit misalignment and tax revenue loss')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %% [markdown]
# # EU total

# %%
# Filter for iso 3 == ESP, FRA, ITA, DEU, NLD, BEL, AUT, DNK, SWE, FIN, IRL, PRT, GRC, CZE, POL, HUN, ROU, BGR, HRV, SVK, SVN, EST, LVA, LTU, MLT, CYP, LUX
sotj_EU = sotj_countries[sotj_countries['iso_partner'].isin(['ESP', 'FRA', 'ITA', 'DEU', 'NLD', 'BEL', 'AUT', 'DNK', 'SWE', 'FIN', 'IRL', 'PRT', 'GRC', 'CZE', 'POL', 'HUN', 'ROU', 'BGR', 'HRV', 'SVK', 'SVN', 'EST', 'LVA', 'LTU', 'MLT', 'CYP', 'LUX'])]

# Drop 2020 and 2021
#sotj_EU = sotj_EU[sotj_EU['year'] != 2020]
#sotj_EU = sotj_EU[sotj_EU['year'] != 2021]

sotj_EU
# Out:
#     iso_partner  year  negative_misalignment  positive_misalignment  \
# 10          AUT  2016                 577.77                 741.10
# 12          AUT  2017               3,954.86               4,751.73
# 12          AUT  2018               4,021.53               1,616.14
# 12          AUT  2019               3,674.10               3,748.11
# 11          AUT  2020               3,213.10               2,280.64
# ..          ...   ...                    ...                    ...
# 181         SWE  2017               2,981.29               9,104.61
# 178         SWE  2018              12,361.83               1,830.49
# 176         SWE  2019               6,303.52               3,341.95
# 178         SWE  2020               6,778.57               2,207.10
# 177         SWE  2021              22,415.37               1,544.34
#
#      theoretical_profit  reported_profit partner_jurisdiction  \
# 10             3,099.57         2,104.41              Austria
# 12            16,045.94        14,816.03              Austria
# 12            20,274.54        14,828.81              Austria
# 12            15,858.25        14,177.88              Austria
# 11            11,154.79         9,171.75              Austria
# ..                  ...              ...                  ...
# 181           16,895.91        19,881.49               Sweden
# 178           44,157.03        14,934.84               Sweden
# 176           23,579.84        16,581.88               Sweden
# 178           16,870.65         7,727.72               Sweden
# 177           35,330.26         4,234.77               Sweden
#
#      etr_average_corrected  cit  tax_revenue_current_usd  \
# 10                    0.09 0.25       100,618,566,642.63
# 12                    0.09 0.25       106,077,073,783.30
# 12                    0.10 0.25       115,647,391,321.69
# 12                    0.10 0.25       113,740,300,610.56
# 11                    0.10 0.25       106,285,791,076.90
# ..                     ...  ...                      ...
# 181                   0.08 0.22       152,174,427,156.66
# 178                   0.08 0.22       155,022,853,925.91
# 176                   0.09 0.21       146,350,803,467.84
# 178                   0.09 0.21       146,220,826,678.30
# 177                   0.09 0.21       174,580,580,951.58
#
#      gvt_health_expenditure region_tjn  ukt  oecd  oecd_oct  nld_oct  \
# 10        29,651,637,133.19     Europe 0.00  1.00      0.00     0.00
# 12        31,978,803,719.19     Europe 0.00  1.00      0.00     0.00
# 12        35,066,488,827.63     Europe 0.00  1.00      0.00     0.00
# 12        34,916,406,196.06     Europe 0.00  1.00      0.00     0.00
# 11        38,026,159,604.30     Europe 0.00  1.00      0.00     0.00
# ..                      ...        ...  ...   ...       ...      ...
# 181       49,425,885,184.20     Europe 0.00  1.00      0.00     0.00
# 178       51,525,920,124.53     Europe 0.00  1.00      0.00     0.00
# 176       49,228,252,063.60     Europe 0.00  1.00      0.00     0.00
# 178       53,429,151,877.22     Europe 0.00  1.00      0.00     0.00
# 177       61,542,341,879.06     Europe 0.00  1.00      0.00     0.00
#
#      tax_revenue_loss  tax_revenue_gain  \
# 10             144.44             68.15
# 12             988.71            446.05
# 12           1,005.38            160.29
# 12             918.52            361.17
# 11             803.28            227.06
# ..                ...               ...
# 181            655.88            756.51
# 178          2,719.60            155.27
# 176          1,348.95            307.25
# 178          1,450.61            200.21
# 177          4,617.57            141.86
#
#      tax_revenue_loss_pct_of_gvt_health_expenditure  \
# 10                                             0.00
# 12                                             0.03
# 12                                             0.03
# 12                                             0.03
# 11                                             0.02
# ..                                              ...
# 181                                            0.01
# 178                                            0.05
# 176                                            0.03
# 178                                            0.03
# 177                                            0.08
#
#      tax_revenue_loss_pct_of_total_tax_revenues  \
# 10                                         0.00
# 12                                         0.01
# 12                                         0.01
# 12                                         0.01
# 11                                         0.01
# ..                                          ...
# 181                                        0.00
# 178                                        0.02
# 176                                        0.01
# 178                                        0.01
# 177                                        0.03
#
#      tax_revenue_loss_caused_pct_of_total  tax_revenue_loss_caused_usd  \
# 10                                   0.00                       205.89
# 12                                   0.00                     1,309.49
# 12                                   0.00                       438.94
# 12                                   0.00                       986.99
# 11                                   0.00                       573.29
# ..                                    ...                          ...
# 181                                  0.01                     2,509.06
# 178                                  0.00                       497.15
# 176                                  0.00                       880.04
# 178                                  0.00                       554.80
# 177                                  0.00                       377.97
#
#      tax_revenue_loss_suffered_pct_of_total
# 10                                     0.00
# 12                                     0.00
# 12                                     0.00
# 12                                     0.00
# 11                                     0.00
# ..                                      ...
# 181                                    0.00
# 178                                    0.01
# 176                                    0.00
# 178                                    0.01
# 177                                    0.01
#
# [162 rows x 23 columns]

# %%
plt.figure(figsize=(10, 6))

for country in sotj_EU['iso_partner'].unique():
    sotj_country = sotj_EU[sotj_EU['iso_partner'] == country]
    plt.plot(sotj_country['year'], sotj_country['positive_misalignment'], label=country)
    plt.text(sotj_country['year'].values[-1], sotj_country['positive_misalignment'].values[-1], country)

plt.title('Yearly total profit misalignment and tax revenue loss')
plt.xlabel('Year')
plt.ylabel('')
plt.ylim(0, )
#plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()
