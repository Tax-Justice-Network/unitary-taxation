# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ## 1. Figures for sample with full reporting

# %%
# Load the CSV files
sotj = pd.read_csv('../output/tables/2024/Sample_with_original_data_only/SOTJ_sample_aggregate_results.csv')
ccctb = pd.read_csv('../output/tables/2024/Sample_with_original_data_only/CCCTB_sample_aggregate_results.csv')
doubleweightedsales = pd.read_csv('../output/tables/2024/Sample_with_original_data_only/double_weighted_sales_sample_aggregate_results.csv')
canadian = pd.read_csv('../output/tables/2024/Sample_with_original_data_only/canadian_formula_sample_aggregate_results.csv')
threefactor = pd.read_csv('../output/tables/2024/Sample_with_original_data_only/three_factor_sample_aggregate_results.csv')

# %%
# Give me the results in non-scientific notation
pd.options.display.float_format = '{:,.2f}'.format
sotj
# Out:
#    year  total_positive_misalignment  total_negative_misalignment  \
# 0  2016                   391,467.67                   391,467.67
# 1  2017                   785,578.84                   785,578.84
# 2  2018                   704,731.19                   704,731.19
# 3  2019                   898,450.14                   898,450.14
# 4  2020                   817,910.92                   817,910.92
# 5  2021                 1,133,582.20                 1,133,582.20
#
#    total_profits  misaligned_of_total_profits  total_tax_revenue_loss  \
# 0   2,234,653.76                         0.18              107,773.01
# 1   4,398,804.66                         0.18              214,290.18
# 2   5,063,961.38                         0.14              187,756.31
# 3   5,252,345.95                         0.17              234,335.15
# 4   3,767,972.07                         0.22              200,386.25
# 5   7,762,091.42                         0.15              275,917.21
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_positive_misalignment'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_positive_misalignment'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_positive_misalignment'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_positive_misalignment'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_positive_misalignment'], label='Three-Factor Formula')

plt.title('Total Misalignment Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Misalignment (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['misaligned_of_total_profits'] * 100, label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['misaligned_of_total_profits'] * 100, label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['misaligned_of_total_profits'] * 100, label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['misaligned_of_total_profits'] * 100, label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['misaligned_of_total_profits'] * 100, label='Three-Factor Formula')

plt.title('Fraction of Profit Shifted Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Fraction of profit shifted (in %)')
plt.ylim(0, 50)  # Set y-axis limits to 0 to 100%
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x)}%'))  # Format y-axis as percentage
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_loss'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_loss'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_loss'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_loss'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_loss'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Loss Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_gain'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_gain'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_gain'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_gain'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_gain'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Gain Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Gain (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.plot(sotj['year'], sotj['total_tax_revenue_gain'], label='SOTJ Formula')
#       3 plt.plot(ccctb['year'], ccctb['total_tax_revenue_gain'], label='CCCTB Formula')
#       4 plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_gain'], label='Double-Weighted Sales Formula')
#
# NameError: name 'sotj' is not defined

# %% [markdown]
# ## 1.1 Definitive Results

# %%
# Concatenate Final Results
scaled_up_2016 = pd.read_csv('../output/tables/2024/Scaling_Mario/SOTJ_sample_aggregate_results_2016.csv')
scaled_up_2017 = pd.read_csv('../output/tables/2024/Scaling_Mario/SOTJ_sample_aggregate_results_2017.csv')
scaled_up_2018 = pd.read_csv('../output/tables/2024/Scaling_Mario/SOTJ_sample_aggregate_results_2018.csv')
scaled_up_2019 = pd.read_csv('../output/tables/2024/Scaling_Mario/SOTJ_sample_aggregate_results_2019.csv')
scaled_up_2020 = pd.read_csv('../output/tables/2024/Scaling_Mario/SOTJ_sample_aggregate_results_2020.csv')
scaled_up_2021 = pd.read_csv('../output/tables/2024/Scaling_Mario/SOTJ_sample_aggregate_results_2021.csv')

#Concatenate all of the above
sotj_scaled_up = pd.concat([scaled_up_2016, scaled_up_2017, scaled_up_2018, scaled_up_2019, scaled_up_2020, scaled_up_2021])

sotj_original = pd.read_csv('../output/tables/2024/Sample_with_original_data_only/SOTJ_sample_aggregate_results.csv')
# Out:
#    year  total_positive_misalignment  total_negative_misalignment  \
# 0  2016                      530,615                      530,615
# 0  2017                    1,011,907                    1,011,907
# 0  2018                      994,586                      994,586
# 0  2019                    1,162,187                    1,162,187
# 0  2020                    1,059,918                    1,059,918
# 0  2021                    1,420,180                    1,420,180
#
#    total_profits  misaligned_of_total_profits  total_tax_revenue_loss  \
# 0      2,661,709                            0                 147,413
# 0      5,271,142                            0                 278,862
# 0      5,989,575                            0                 270,126
# 0      6,044,145                            0                 306,039
# 0      4,430,344                            0                 266,432
# 0      8,934,613                            0                 347,579
#
# ...

# %%
#Filter sotj_scaled_up - take out first row
sotj_scaled_up = sotj_scaled_up[sotj_scaled_up['year'] != 2016]

# Give me the average of the column total_positive_misalignment
sotj_scaled_up['total_positive_misalignment'].mean()
sotj_scaled_up['total_tax_revenue_loss'].mean()

#Give me the number without commas
# Out:
# 293807.5836746062

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj_original['year'], sotj_original['total_positive_misalignment'], label='SOTJ - Full Reporters')
plt.plot(sotj_scaled_up['year'], sotj_scaled_up['total_positive_misalignment'], label='SOTJ Scaled Up - Including Incomplete Reporters')


plt.title('Total Misalignment Over the Years, based on CBCR reporting countries')
plt.xlabel('Year')
plt.ylabel('Total Misalignment (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj_original['year'], sotj_original['misaligned_of_total_profits'] * 100, label='SOTJ - Full Reporters')
plt.plot(sotj_scaled_up['year'], sotj_scaled_up['misaligned_of_total_profits'] * 100, label='SOTJ Scaled Up - Including Incomplete Reporters')

plt.title('Fraction of Profit Shifted Over the Years, based on CBCR reporting countries')
plt.xlabel('Year')
plt.ylabel('Fraction of profit shifted (in %)')
plt.ylim(0, 50)  # Set y-axis limits to 0 to 100%
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x)}%'))  # Format y-axis as percentage
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj_original['year'], sotj_original['total_tax_revenue_loss'], label='SOTJ - Full Reporters')
plt.plot(sotj_scaled_up['year'], sotj_scaled_up['total_tax_revenue_loss'], label='SOTJ Scaled Up - Including Incomplete Reporters')

plt.title('Total Tax Revenue Loss Over the Years, based on CBCR reporting countries')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj_original['year'], sotj_original['total_tax_revenue_gain'], label='SOTJ - Full Reporters')
plt.plot(sotj_scaled_up['year'], sotj_scaled_up['total_tax_revenue_gain'], label='SOTJ Scaled Up - Including Incomplete Reporters')

plt.title('Total Tax Revenue Gain Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Gain (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %% [markdown]
# ## 1.2 Figures for Sample with Original Data Only Foreign Profits

# %%
# Load the CSV files
sotj = pd.read_csv('../output/tables/2024/Sample_with_original_data_only_foreign_profits/SOTJ_f_sample_aggregate_results.csv')
ccctb = pd.read_csv('../output/tables/2024/Sample_with_original_data_only_foreign_profits/CCCTB_f_sample_aggregate_results.csv')
doubleweightedsales = pd.read_csv('../output/tables/2024/Sample_with_original_data_only_foreign_profits/double_weighted_sales_f_sample_aggregate_results.csv')
canadian = pd.read_csv('../output/tables/2024/Sample_with_original_data_only_foreign_profits/canadian_formula_f_sample_aggregate_results.csv')
threefactor = pd.read_csv('../output/tables/2024/Sample_with_original_data_only_foreign_profits/three_factor_f_sample_aggregate_results.csv')

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_positive_misalignment'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_positive_misalignment'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_positive_misalignment'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_positive_misalignment'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_positive_misalignment'], label='Three-Factor Formula')

plt.title('Total Misalignment Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Misalignment (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['misaligned_of_total_profits'] * 100, label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['misaligned_of_total_profits'] * 100, label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['misaligned_of_total_profits'] * 100, label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['misaligned_of_total_profits'] * 100, label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['misaligned_of_total_profits'] * 100, label='Three-Factor Formula')

plt.title('Fraction of Profit Shifted Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Fraction of profit shifted (in %)')
plt.ylim(0, 70)  # Set y-axis limits to 0 to 100%
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x)}%'))  # Format y-axis as percentage
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_loss'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_loss'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_loss'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_loss'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_loss'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Loss Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_gain'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_gain'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_gain'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_gain'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_gain'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Gain Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Gain (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %% [markdown]
# ## 1.3 Figures for Sample with Original Data Only Foreign Profits Scaled Up

# %%
# Load the CSV files
sotj = pd.read_csv('../output/tables/2024/Sample_with_origina_data_only_fp_scaled/SOTJ_f_scaled_sample_aggregate_results.csv')
ccctb = pd.read_csv('../output/tables/2024/Sample_with_origina_data_only_fp_scaled/CCCTB_f_scaled_sample_aggregate_results.csv')
doubleweightedsales = pd.read_csv('../output/tables/2024/Sample_with_origina_data_only_fp_scaled/double_weighted_sales_f_scaled_sample_aggregate_results.csv')
canadian = pd.read_csv('../output/tables/2024/Sample_with_origina_data_only_fp_scaled/canadian_formula_f_scaled_sample_aggregate_results.csv')
threefactor = pd.read_csv('../output/tables/2024/Sample_with_origina_data_only_fp_scaled/three_factor_f_scaled_sample_aggregate_results.csv')

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_positive_misalignment'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_positive_misalignment'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_positive_misalignment'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_positive_misalignment'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_positive_misalignment'], label='Three-Factor Formula')

plt.title('Total Misalignment Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Misalignment (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['misaligned_of_total_profits'] * 100, label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['misaligned_of_total_profits'] * 100, label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['misaligned_of_total_profits'] * 100, label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['misaligned_of_total_profits'] * 100, label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['misaligned_of_total_profits'] * 100, label='Three-Factor Formula')

plt.title('Fraction of Profit Shifted Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Fraction of profit shifted (in %)')
plt.ylim(0, 200)  # Set y-axis limits to 0 to 100%
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x)}%'))  # Format y-axis as percentage
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_loss'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_loss'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_loss'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_loss'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_loss'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Loss Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_gain'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_gain'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_gain'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_gain'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_gain'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Gain Over the Years, based on full reporting countries only')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Gain (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Figures for reporting sample, aggregate values are predicted and scaled

# %%
# Load the CSV files
sotj = pd.read_csv('../output/tables/2024/Sample_of_original_reporters_filled_missings/SOTJ_sample_filled_aggregate_results.csv')
ccctb = pd.read_csv('../output/tables/2024/Sample_of_original_reporters_filled_missings/CCCTB_sample_filled_aggregate_results.csv')
doubleweightedsales = pd.read_csv('../output/tables/2024/Sample_of_original_reporters_filled_missings/double_weighted_sales_sample_filled_aggregate_results.csv')
canadian = pd.read_csv('../output/tables/2024/Sample_of_original_reporters_filled_missings/canadian_formula_sample_filled_aggregate_results.csv')
threefactor = pd.read_csv('../output/tables/2024/Sample_of_original_reporters_filled_missings/three_factor_sample_filled_aggregate_results.csv')

# %%
plt.figure(figsize=(10, 6))
#plt.plot(sotj['year'], sotj['total_positive_misalignment'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_positive_misalignment'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_positive_misalignment'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_positive_misalignment'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_positive_misalignment'], label='Three-Factor Formula')

plt.title('Total Misalignment Over the Years, based on reporting countries')
plt.xlabel('Year')
plt.ylabel('Total Misalignment (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
#plt.plot(sotj['year'], sotj['misaligned_of_total_profits'] * 100, label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['misaligned_of_total_profits'] * 100, label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['misaligned_of_total_profits'] * 100, label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['misaligned_of_total_profits'] * 100, label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['misaligned_of_total_profits'] * 100, label='Three-Factor Formula')

plt.title('Fraction of Profit Shifted Over the Years, based on reporting countries')
plt.xlabel('Year')
plt.ylabel('Fraction of profit shifted (in %)')
plt.ylim(0, 45)  # Set y-axis limits to 0 to 100%
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x)}%'))  # Format y-axis as percentage
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
#plt.plot(sotj['year'], sotj['total_tax_revenue_loss'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_loss'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_loss'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_loss'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_loss'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Loss Over the Years, based on reporting countries')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
#plt.plot(sotj['year'], sotj['total_tax_revenue_gain'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_gain'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_gain'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_gain'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_gain'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Gain Over the Years, based on reporting countries')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Gain (in million USD)')
plt.ylim(0, )
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. Figures for global sample with imputed values

# %%
# Load the CSV files
sotj = pd.read_csv('../output/tables/2024/Global_sample_with_imputed_data/One_sample/SOTJ_global_sample_aggregate_results.csv')
sotj = sotj[sotj['year'] != 2016]
ccctb = pd.read_csv('../output/tables/2024/Global_sample_with_imputed_data/One_sample/CCCTB_global_sample_aggregate_results.csv')
ccctb = ccctb[ccctb['year'] != 2016]
doubleweightedsales = pd.read_csv('../output/tables/2024/Global_sample_with_imputed_data/One_sample/double_weighted_sales_global_sample_aggregate_results.csv')
doubleweightedsales = doubleweightedsales[doubleweightedsales['year'] != 2016]
canadian = pd.read_csv('../output/tables/2024/Global_sample_with_imputed_data/One_sample/canadian_formula_global_sample_aggregate_results.csv')
canadian = canadian[canadian['year'] != 2016]
threefactor = pd.read_csv('../output/tables/2024/Global_sample_with_imputed_data/One_sample/three_factor_global_sample_aggregate_results.csv')
threefactor = threefactor[threefactor['year'] != 2016]

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_positive_misalignment'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_positive_misalignment'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_positive_misalignment'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_positive_misalignment'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_positive_misalignment'], label='Three-Factor Formula')

plt.title('Total Misalignment Over the Years, Global Estimate')
plt.xlabel('Year')
plt.ylabel('Total Misalignment (in million USD)')
plt.ylim(0, )

# Set x ticks to show only full years
years = sorted(set(sotj['year']).union(set(ccctb['year'])).union(set(doubleweightedsales['year'])).union(set(canadian['year'])).union(set(threefactor['year'])))
plt.xticks(years)  # Set x ticks to the unique years

plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['misaligned_of_total_profits'] * 100, label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['misaligned_of_total_profits'] * 100, label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['misaligned_of_total_profits'] * 100, label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['misaligned_of_total_profits'] * 100, label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['misaligned_of_total_profits'] * 100, label='Three-Factor Formula')

plt.title('Fraction of Profit Shifted Over the Years, global estimate')
plt.xlabel('Year')
plt.ylabel('Fraction of profit shifted (in %)')
plt.ylim(0, 45)  # Set y-axis limits to 0 to 100%

# Set x ticks to show only full years
years = sorted(set(sotj['year']).union(set(ccctb['year'])).union(set(doubleweightedsales['year'])).union(set(canadian['year'])).union(set(threefactor['year'])))
plt.xticks(years)  # Set x ticks to the unique years
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x)}%'))  # Format y-axis as percentage
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_loss'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_loss'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_loss'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_loss'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_loss'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Loss Over the Years, global estimate')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Loss (in million USD)')
plt.ylim(0, )

# Set x ticks to show only full years
years = sorted(set(sotj['year']).union(set(ccctb['year'])).union(set(doubleweightedsales['year'])).union(set(canadian['year'])).union(set(threefactor['year'])))
plt.xticks(years)  # Set x ticks to the unique years
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sotj['year'], sotj['total_tax_revenue_gain'], label='SOTJ Formula')
plt.plot(ccctb['year'], ccctb['total_tax_revenue_gain'], label='CCCTB Formula')
plt.plot(doubleweightedsales['year'], doubleweightedsales['total_tax_revenue_gain'], label='Double-Weighted Sales Formula')
plt.plot(canadian['year'], canadian['total_tax_revenue_gain'], label='Canadian Formula')
plt.plot(threefactor['year'], threefactor['total_tax_revenue_gain'], label='Three-Factor Formula')

plt.title('Total Tax Revenue Gain Over the Years, global estimate')
plt.xlabel('Year')
plt.ylabel('Total Tax Revenue Gain (in million USD)')
plt.ylim(0, )

# Set x ticks to show only full years
years = sorted(set(sotj['year']).union(set(ccctb['year'])).union(set(doubleweightedsales['year'])).union(set(canadian['year'])).union(set(threefactor['year'])))
plt.xticks(years)  # Set x ticks to the unique years
plt.legend()
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{x:,.0f}'))
plt.grid(True)
plt.show()
